# %%
# example code for visualization the EDFA gain spectrum dataset
from libs.edfa_examples import *

# %% [markdown]
# Topic 1: visualize gain spectrum for any EDFA

# %%
edfaType,gain,channelType,roadmName = "booster","18dB","random","rdm1-co1"
plot_one_json_file_gain_spectrum(edfaType,gain,channelType,roadmName)
# Out:
# ../dataset/booster/18dB/random/edfa_meas_rdm1-co1.bed_booster_2022.03.28.19.36.33.json

# %% [markdown]
# Topic 2: visualize arbitrary features from the dataset

# %%
# get from website introduction or README / 
edfaType,gain,channelType,roadmName = "preamp","18dB","fix","rdm1-co1"
# edfaType,gain,channelType,roadmName,subChannelName,spectrumName
subChannelName,spectrumName = "fully_loaded_channel_wdm","roadm_dut_preamp_input_power_spectra"
plot_json_one_element(edfaType,gain,channelType,roadmName,subChannelName,spectrumName)
# Out:
# {   '1': -21.6,
#     '10': -17.9,
#     '11': -17.8,
#     '12': -17.9,
#     '13': -17.9,
#     '14': -17.9,
#     '15': -17.9,
#     '16': -18.0,
#     '17': -17.9,
#     '18': -17.9,
#     '19': -17.9,
#     '2': -19.8,
#     '20': -17.9,
#     '21': -17.9,
#     '22': -17.9,
#     '23': -17.9,
#     '24': -17.9,
#     '25': -17.9,
#     '26': -17.9,
#     '27': -17.9,
#     '28': -17.9,
#     '29': -17.9,
#     '3': -18.0,
#     '30': -17.9,
#     '31': -17.8,
#     '32': -17.9,
#     '33': -18.0,
#     '34': -17.9,
#     '35': -17.9,
#     '36': -17.9,
#     '37': -17.9,
#     '38': -17.8,
#     '39': -18.0,
#     '4': -18.0,
#     '40': -18.0,
#     '41': -17.8,
#     '42': -17.9,
#     '43': -17.9,
#     '44': -17.9,
#     '45': -17.9,
#     '46': -18.0,
#     '47': -18.0,
#     '48': -17.9,
#     '49': -17.8,
#     '5': -18.0,
#     '50': -17.9,
#     '51': -18.0,
#     '52': -17.9,
#     '53': -17.8,
#     '54': -17.9,
#     '55': -17.9,
#     '56': -18.0,
#     '57': -17.8,
#     '58': -17.9,
#     '59': -17.8,
#     '6': -17.8,
#     '60': -17.8,
#     '61': -17.9,
#     '62': -17.9,
#     '63': -18.0,
#     '64': -17.9,
#     '65': -17.9,
#     '66': -17.9,
#     '67': -18.0,
#     '68': -18.0,
#     '69': -17.9,
#     '7': -17.8,
#     '70': -17.9,
#     '71': -17.9,
#     '72': -17.9,
#     '73': -17.9,
#     '74': -17.9,
#     '75': -17.9,
#     '76': -17.8,
#     '77': -17.9,
#     '78': -17.9,
#     '79': -18.0,
#     '8': -17.9,
#     '80': -17.9,
#     '81': -17.9,
#     '82': -17.9,
#     '83': -17.9,
#     '84': -17.9,
#     '85': -17.9,
#     '86': -18.1,
#     '87': -17.9,
#     '88': -17.9,
#     '89': -18.0,
#     '9': -17.9,
#     '90': -17.9,
#     '91': -17.9,
#     '92': -17.9,
#     '93': -18.0,
#     '94': -17.9,
#     '95': -17.9}

# %% [markdown]
# Topic 3: generating CSV file for ML training from different channel types, EDFA types, gain lists, and ROADM index

# %%
channelTypes = ['fix', 'random', 'extraRandom', 'extraLow']
edfaTypes = ["booster"] # ["booster","preamp"]
roadmNames = ['rdm1-co1'] # ['rdm1-co1', 'rdm2-co1', 'rdm3-co1', 'rdm4-co1',
                        # 'rdm5-co1', 'rdm6-co1', 'rdm1-lg1', 'rdm2-lg1']
gainLists = ["15dB","18dB","21dB"]
generate_ML_features(edfaTypes,gainLists,roadmNames,channelTypes)
# check the generated csv files at "misc/ML_features" folder
# Out:
# processing: rdm1-co1
# processing: fix
# processing: 15dB
# processing: 18dB
# processing: 21dB
# processing: random
# processing: 15dB
# processing: 18dB
# processing: 21dB
# processing: extraRandom
# processing: 15dB
# processing: 18dB
# processing: 21dB
# processing: extraLow
# processing: 15dB
# processing: 18dB
# processing: 21dB

# %% [markdown]
# Topic 4: clean CSVs

# %%
remove_generated_files()
